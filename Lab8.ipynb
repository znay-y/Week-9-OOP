// %% [markdown]
// # Lab 8

// %% [markdown]
// ### Name:
// ### Student ID:

// %% [markdown]
// ***
//
// ## Question 1 [0.75 marks]

// %% [markdown]
// Write a method:

// %%
static String getElement(String[] array, int index) {
        try {
            return array[index];
        } catch (Exception e) {
            System.out.println("Index is out of array");
            return null;
        }
    }

// %% [markdown]
// that returns the element at the given index.
//
// - Identify the exception that may occur.
// - Handle the exception using a `try-catch` block.
// - If an exception occurs, print an appropriate message and return `null`.

// %% [markdown]
// ***
//
// ## Question 2 [0.75 marks]

// %% [markdown]
// Write a program that:
//
// 1. Prompts the user to enter two integers.
// 2. Divides the first number by the second.
//
// Your program must handle the following exceptions using **separate** `catch` blocks:
//
// - `ArithmeticException`
// - `NumberFormatException`
//
// If an exception occurs, print an appropriate message.

// %%
public static void main(String[] args) {
        int first = numberIN("Enter the first number");
        int second = numberIN("Encter your second number");

        try {
            System.out.println(first / second);
        } catch (ArithmeticException e) {
            System.out.println("Cannot divide those numbers");
        }
    }

    public static int numberIN(String message) {
        Scanner kmb = new Scanner(System.in);
        System.out.println(message);
        String input = kmb.nextLine();

        try {
            int num = Integer.parseInt(input);
            return num;
        } catch (NumberFormatException e) {
            System.out.println("I SAIDDDDD enter a number");
            return 0;
        }

    }

// %% [markdown]
// ***
// ## Question 3 [0.75 marks]

// %% [markdown]
// Write a method:

// %%
static int getStringLength(String s){
   try {
        return s.length();
    } catch (NullPointerException e) {
        System.out.println("Null passed :(");
        return 0;
    }
    finally{
        System.out.println("Execution completed");
    }
        
     
}

// %% [markdown]
// that returns the length of a string.
//
// - Use a `try-catch-finally` structure.
// - Handle the case where the string is `null`.
// - The `finally` block must print a message such as `"Execution completed"`.

// %% [markdown]
// ***

// %% [markdown]
// ## Question 4 [0.75 marks]

// %% [markdown]
// Define your own custom exception called:

// %%
InvalidInputException

// %% [markdown]
// Your exception must:
//
// - Extend `Exception`
// - Include a constructor that accepts a message
// - Return the message when the exception is printed

// %% [markdown]
// ## Question 5 [2 marks]

// %% [markdown]
// Write a method:

// %%
static String processName(String name) throws InvalidInputException

// %% [markdown]
// that processes a given string according to the following rules:
//
// - If `name` is `null`, throw an `InvalidInputException`
// - If `name` is empty, throw an `InvalidInputException`
// - Otherwise, return the name in **uppercase**
//
// Then:
//
// - Call this method inside a `try` block
// - Catch the exception and print its message

// %% [markdown]
// **Examples**

// %%
processName("Alice") → "ALICE"
processName("")      → exception
processName(null)    → exception
